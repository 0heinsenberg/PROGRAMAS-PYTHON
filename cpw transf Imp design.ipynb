# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(4,8,1000) *(10**9)
x=40 #Ohms
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
y=2.5 * 10**(-12)

wt1= (4.8 * 10**(9))
wt2= (5 * 10**(9))
wt3= (5.2 * 10**(9))
wt4= (5.4 * 10**(9))
wt5= (5.6 * 10**(9)) #Hz
wt6= (5.8 * 10**(9)) #Hz
wt7= (6 * 10**(9)) #Hz
wt8= (6.2 * 10**(9)) #Hz
wt9= (6.4 * 10**(9)) #Hz
wt10= (6.6 * 10**(9))
wt11= (6.8 * 10**(9))
wt12= (7 * 10**(9))
wt13= (7.2 * 10**(9))
wt14= (7.4 * 10**(9))
wt15= (7.6 * 10**(9))



#OMEGA T = wt1
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt1)* 2 * (np.pi) #
#beta=0.01
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt1)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste1 = BW_MHz
BWteste1[G0 < 15] = 0
BWteste1[f<wt1]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
f_GHz= f * (10**(-9))
plt.plot(f_GHz,BWteste1, label = 'line1')

#OMEGA T = wt2
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt2)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt2)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste2 = BW_MHz
BWteste2[G0 < 15] = 0
BWteste2[f<wt2]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste2, label = 'line2')


#OMEGA T = wt3
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt3)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt3)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste3 = BW_MHz
BWteste3[G0 < 15] = 0
BWteste3[f<wt3]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste3, label = 'line3')


#OMEGA T = wt4
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt4)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt4)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste4 = BW_MHz
BWteste4[G0 < 15] = 0
BWteste4[f<wt4]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste4, label = 'line4')

#OMEGA T = wt5
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt5)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt5)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste5 = BW_MHz
BWteste5[G0 < 15] = 0
BWteste5[f < wt5]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste5, label = 'line5')

#OMEGA T = wt6
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt6)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt6)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste6 = BW_MHz
BWteste6[G0 < 15] = 0
BWteste6[f<wt6]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste6, label = 'line6')

#OMEGA T = wt7
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt7)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt7)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste7 = BW_MHz
BWteste7[G0 < 15] = 0
BWteste7[f<wt7]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste7, label = 'line7')

#OMEGA T = wt8
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt8)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt8)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste8 = BW_MHz
BWteste8[G0 < 15] = 0
BWteste8[f<wt8]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste8, label = 'line8')

#OMEGA T = wt9
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt9)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt9)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste9 = BW_MHz
BWteste9[G0 < 15] = 0
BWteste9[f<wt9]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste9, label = 'line9')

#OMEGA T = wt10
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt10)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt10)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste10 = BW_MHz
BWteste10[G0 < 15] = 0
BWteste10[f<wt10]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste10, label = "line10")

#OMEGA T = wt11
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt11)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt11)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste11 = BW_MHz
BWteste11[G0 < 15] = 0
BWteste11[f<wt11]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste11, label = "line11")

#OMEGA T = wt12
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt12)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt12)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste12 = BW_MHz
BWteste12[G0 < 15] = 0
BWteste12[f<wt12]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste12, label = "line12")

#OMEGA T = wt13
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt13)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt13)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste13 = BW_MHz
BWteste13[G0 < 15] = 0
BWteste13[f<wt13]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste13, label = "line13")


#OMEGA T = wt10
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt14)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt14)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste14 = BW_MHz
BWteste14[G0 < 15] = 0
BWteste14[f<wt14]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste14, label = "line14")


#OMEGA T = wt15
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt15)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt15)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste15 = BW_MHz
BWteste15[G0 < 15] = 0
BWteste15[f<wt15]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste15, label = "line15")


plt.axhline(y=500, linestyle='--')







plt.ylabel('BW [MHz]')
plt.xlabel(r'$\Omega_p$ [GHz]')


plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(4,8,1000) *(10**9)
x=40 #Ohms
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
y=2.5 * 10**(-12)

wt1= (4.8 * 10**(9))
wt2= (5 * 10**(9))
wt3= (5.2 * 10**(9))
wt4= (5.4 * 10**(9))
wt5= (5.6 * 10**(9)) #Hz
wt6= (5.8 * 10**(9)) #Hz
wt7= (6 * 10**(9)) #Hz
wt8= (6.2 * 10**(9)) #Hz
wt9= (6.4 * 10**(9)) #Hz
wt10= (6.6 * 10**(9))
wt11= (6.8 * 10**(9))
wt12= (7 * 10**(9))
wt13= (7.2 * 10**(9))
wt14= (7.4 * 10**(9))
wt15= (7.6 * 10**(9))



#OMEGA T = wt1
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt1)* 2 * (np.pi) #
#beta=0.01
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt1)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G01=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G01)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste1 = BW_MHz
BWteste1[G01 < 15] = 0
BWteste1[f<wt1]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
f_GHz= f * (10**(-9))
plt.plot(f_GHz,G01, label = 'line1')

#OMEGA T = wt2
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt2)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt2)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G02=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste2 = BW_MHz
BWteste2[G02 < 15] = 0
BWteste2[f<wt2]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,G02, label = 'line2')


#OMEGA T = wt3
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt3)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt3)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G03=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G03)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste3 = BW_MHz
BWteste3[G03 < 15] = 0
BWteste3[f<wt3]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,G03, label = 'line3')


#OMEGA T = wt4
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt4)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt4)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G04=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G04)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste4 = BW_MHz
BWteste4[G04 < 15] = 0
BWteste4[f<wt4]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,G04, label = 'line4')

#OMEGA T = wt5
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt5)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt5)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G05=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G05)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste5 = BW_MHz
BWteste5[G05 < 15] = 0
BWteste5[f < wt5]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,G05, label = 'line5')

#OMEGA T = wt6
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt6)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt6)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G06=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G06)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste6 = BW_MHz
BWteste6[G06 < 15] = 0
BWteste6[f<wt6]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,G06, label = 'line6')

#OMEGA T = wt7
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt7)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt7)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste7 = BW_MHz
BWteste7[G0 < 15] = 0
BWteste7[f<wt7]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste7, label = 'line7')

#OMEGA T = wt8
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt8)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt8)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste8 = BW_MHz
BWteste8[G0 < 15] = 0
BWteste8[f<wt8]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste8, label = 'line8')

#OMEGA T = wt9
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt9)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt9)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste9 = BW_MHz
BWteste9[G0 < 15] = 0
BWteste9[f<wt9]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste9, label = 'line9')

#OMEGA T = wt10
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt10)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt10)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste10 = BW_MHz
BWteste10[G0 < 15] = 0
BWteste10[f<wt10]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste10, label = "line10")

#OMEGA T = wt11
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt11)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt11)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste11 = BW_MHz
BWteste11[G0 < 15] = 0
BWteste11[f<wt11]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste11, label = "line11")

#OMEGA T = wt12
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt12)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt12)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste12 = BW_MHz
BWteste12[G0 < 15] = 0
BWteste12[f<wt12]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste12, label = "line12")

#OMEGA T = wt13
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt13)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt13)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste13 = BW_MHz
BWteste13[G0 < 15] = 0
BWteste13[f<wt13]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste13, label = "line13")


#OMEGA T = wt10
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt14)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt14)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste14 = BW_MHz
BWteste14[G0 < 15] = 0
BWteste14[f<wt14]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste14, label = "line14")


#OMEGA T = wt15
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f

k0=1/(R * 2 * y)
wd=(omegap-wt15)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt15)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))

BW_MHz=BW * 10**(-6)

BWteste15 = BW_MHz
BWteste15[G0 < 15] = 0
BWteste15[f<wt15]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
plt.plot(f_GHz,BWteste15, label = "line15")


plt.axhline(y=500, linestyle='--')







plt.ylabel('BW [MHz]')
plt.xlabel(r'$\Omega_p$ [GHz]')


plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(4,8,1000) *(10**9)
x=40 #Ohms
y=2.5 * 10**(-12)


wt=(6 * 10**(9)) #Hz
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=2*(10**(-6))
lp=phi0/(2*(np.pi)*Ic)

zp=np.sqrt(lp/y)

#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))
#k0=R/((x**2)*y) #1.5e10
k02=1/(R * 2 * y)
k01=omegap*zp/R

wd=(omegap-wt)* 2 * (np.pi) #

beta1=(2*wd)/((np.sqrt(3))*k01)
beta2= (2 * wd)/((np.sqrt(3)) * (k02))
lamb= (k02 * (1 + (3 * beta2**2))**0.5)/(12**0.5)
rl=(x**2)/R
G01=1+((3*(pt1-pt2))**(-1))
G02=1+(((4*k0*lamb)**2)/((k02**2-4*(lamb**2-wd**2))**2))
#G01_grande=G01
#G01_grande[G01<0]=


BW1=(k01/2)*((1/G01)**((1/2)))
BW2=(k02/2)*((1/G02)**((1/4)))
#BW1[G01<15]=0

ganho1=G01/(1+(wd/BW1)**2)
ganho2=G02/(1+(wd/BW2)**4)


#BW1_MHz=BW * 10**(-6)
#BWteste = BW_MHz
#BWteste[G0 < 18] = 0
#BWteste[f<wt]=0
#BWteste[BW_MHz < 300]=0
#BWteste[BW_MHz > 900]=0

ganho1_dB = 10 * np.log10(ganho1)
ganho2_dB = 10 * np.log10(ganho2)


#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz, ganho1_dB, label = 'line')
#plt.semilogy()
plt.ylabel('Ganho [dB]')
plt.xlabel(r'$Frequência$ [GHz]')
#plt.axhline(y=500, linestyle='--')
f_GHz=f * (10**(-9))
plt.plot(f_GHz, ganho2_dB, label = 'line')
#plt.semilogy()
plt.ylabel('Ganho [dB]')
plt.xlabel(r'$Frequência$ [GHz]')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 49
#      47 lamb= (k02 * (1 + (3 * beta2**2))**0.5)/(12**0.5)
#      48 rl=(x**2)/R
# ---> 49 G01=1+((3*(pt1-pt2))**(-1))
#      50 G02=1+(((4*k0*lamb)**2)/((k02**2-4*(lamb**2-wd**2))**2))
#      51 #G01_grande=G01
#      52 #G01_grande[G01<0]=
#
# NameError: name 'pt1' is not defined

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(4.8,5.5,1000) *(10**9)
x=40 #Ohms
y=2.5 * 10**(-12)

wt=(5 * 10**(9)) #Hz
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))
#k0=R/((x**2)*y) #1.5e10
k0=1/(R * 2 * y)
wd=(omegap-wt)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((x**2)/(y2**2 * R**2)))))
#alpha=((np.pi) /(2*wt)) * ((x * (1-(rl/R))) + (2 * y2 *(1-((rl/y2)**2))))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4        
BW=(k0/2)*((1/G0)**((1/4)))



BW_MHz=BW * 10**(-6)
BWteste = BW_MHz
BWteste[G0 < 18] = 0
BWteste[f<wt]=0
#BWteste[BW_MHz < 300]=0
#BWteste[BW_MHz > 900]=0

#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz,BWteste, label = 'line')
plt.ylabel('BW [MHz]')
plt.xlabel(r'$\Omega_p$ [GHz]')
plt.axhline(y=500, linestyle='--')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(5,8,1000) *(10**9)
x=40
y=2.5 * 10**(-12)

wt=(6 * 10**(9)) #Hz
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))


#k0=R/((x**2)*y) #1.5e10
k0=1/(R * 2 * y)
wd=(omegap-wt)* 2 * (np.pi)
beta= (2 * wd)/((np.sqrt(3)) * (k0))
#lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
#rl=(x**2)/R
#alpha=((np.pi) /(2*wt)) * ((x * (1-(rl/R))) + (2 * y2 *(1-(rl/y2)**2)))
#g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
Gmax=1+ (3 * (1 + (7 * beta**2) - (4 * beta *(np.sqrt(1 + (3 * beta**2))))))**(-1)
BW=(k0/2)*((1/Gmax)**((1/4)))



BW_MHz=BW * 10**(-6)

BWteste = BW_MHz
BWteste[Gmax < 18] = 0
#BWteste[f<wt]=0
#BWteste[BW < 300000000]=0
#BWteste[BW_MHz > 900]=0

#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz,BW_MHz)
plt.ylabel('BW [MHz]')
plt.xlabel(r'$\Omega_p$ [GHz]')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
##gráfico 1
X = np.linspace(20, 50, 1000)
Y = np.linspace(1,6,1000) * (10**(-12))
Zlamb_4, y = np.meshgrid(X, Y)
C = np.flip(y)

#constantes gráfico 1
wt=(7 * 10**(9)) #Hz
omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
R=50 #ohms
Zlamb_2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=2.4*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))

#cálculo gráfico 1
k0=1/(R * 2 * C)
wd=(omegap-wt)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(Zlamb_4**2)/R

alpha=((np.pi) /(2*wt)) * ((Zlamb_4 * (1-(rl/R))) + (2 * Zlamb_2 *(1-(rl/Zlamb_2)**2)))
g1=((alpha*R)/(Zlamb_4**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+(((2)*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4

BW=(k0/2)*((1/G0)**((1/4)))


BW_MHz=BW * 10**(-6)
BWteste = BW_MHz
BWteste[G0 < 18] = 0
BWteste[BW_MHz < 300]=0
BWteste[BW_MHz > 1000]=0


##gráfico 2
X1 = np.linspace(20, 50, 1000)
Y1 = np.linspace(20, 70, 1000)
Z_lamb_s_4,Z_lamb_s_2 = np.meshgrid (X1, Y1)
Z_lamb_s_2=np.flip(Z_lamb_s_2)

#constantes gráfico 2
omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
R=50 #ohms
cp=2 * (10**(-12)) #Faraday
phi0=2.06783*(10**(-15))
Ic=3.2*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))

#cálculo gráfico 2
k0=1/(R * 2 * cp)
wd=(omegap-wt)* 2 * (np.pi) #
print(wd)
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(Z_lamb_s_4**2)/R

alpha=((np.pi) /(2*wt)) * ((Z_lamb_s_4 * (1-(rl/R))) + (2 * Z_lamb_s_2 *(1-(rl/Z_lamb_s_2)**2)))
g1=((alpha*R)/(Z_lamb_s_4**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+(((2)*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4

BW=(k0/2)*((1/G0)**((1/4)))


BW_MHz=BW * 10**(-6)
BWteste1 = BW_MHz
BWteste1[G0 < 18] = 0
BWteste1[BW_MHz < 300]=0
BWteste1[BW_MHz > 1000]=0

#gráficos
#grafico1
plt.contourf(Zlamb_4, C, BWteste,cmap='gist_heat')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center', fontsize=20)
ticklabs = clb.ax.get_yticklabels()
clb.ax.set_yticklabels(ticklabs, fontsize=15)
plt.title(r'$Z_{\lambda/2}$ = 60 $\Omega$', fontsize=20)
plt.ylabel(r'$C_p$ [pF]', fontsize=20)
plt.xlabel(r'$Z_{\lambda/4}$', fontsize=20)
plt.plot(38, (cp), "-o", color='black')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

#gráfico2
plt.contourf(Z_lamb_s_4,Z_lamb_s_2, BWteste1,cmap='gist_heat')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center', fontsize=20)
ticklabs = clb.ax.get_yticklabels()
clb.ax.set_yticklabels(ticklabs, fontsize=15)
plt.title(r'$C_p$ = 2 pF', fontsize=20)
plt.plot(38, 60, "o", color='black')
plt.ylabel(r'$Z_{\lambda/2}$ [$\Omega$]', fontsize=20)
plt.xlabel(r'$Z_{\lambda/4}$ [$\Omega$]', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # OUTRO TIPO DE MANEIRA

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

##gráfico 1
X = np.linspace(20, 50, 1000)
Y = np.linspace(1,6,1000) * (10**(-12))
Zlamb_4, y = np.meshgrid(X, Y)
C = np.flip(y)

#constantes gráfico 1
wt=(7 * 10**(9)) #Hz
omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
R=50 #ohms
Zlamb_2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))

#cálculo gráfico 1
k0=1/(R * 2 * C)
wd=(omegap-wt)* 2 * (np.pi) #
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(Zlamb_4**2)/R

alpha=((np.pi) /(2*wt)) * ((Zlamb_4 * (1-(rl/R))) + (2 * Zlamb_2 *(1-(rl/Zlamb_2)**2)))
g1=((alpha*R)/(Zlamb_4**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+(((2)*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4

BW=(k0/2)*((1/G0)**((1/4)))


BW_MHz=BW * 10**(-6)
BWteste = BW_MHz
BWteste[G0 < 18] = 0
BWteste[BW_MHz < 300]=0
BWteste[BW_MHz > 1000]=0


#grafico1
plt.contourf(Zlamb_4, C, BWteste,cmap='gist_heat')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center', fontsize=20)
ticklabs = clb.ax.get_yticklabels()
clb.ax.set_yticklabels(ticklabs, fontsize=15)
plt.title(r'$Z_{\lambda/2}$ = 60 $\Omega$', fontsize=20)
plt.ylabel(r'$C_p$ [pF]', fontsize=20)
plt.xlabel(r'$Z_{\lambda/4}$', fontsize=20)
#plt.plot(40, (cp), "-o")
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
Z_jpa



Z_aux=eta*(R**2)/Z_jpa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Z_jpa
#       5 Z_aux=eta*(R**2)/Z_jpa
#
# NameError: name 'Z_jpa' is not defined

# %%
#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores



##gráfico 2
X1 = np.linspace(20, 50, 1000)
Y1 = np.linspace(20, 70, 1000)
Z_lamb_s_4,Z_lamb_s_2 = np.meshgrid (X1, Y1)
Z_lamb_s_2=np.flip(Z_lamb_s_2)

#constantes gráfico 2
omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
R=50 #ohms
cp=3 * (10**(-12)) #Faraday
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))

#cálculo gráfico 2
k0=1/(R * 2 * cp)
wd=(omegap-wt)* 2 * (np.pi) #
#print(wd)
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(Z_lamb_s_4**2)/R

alpha=((np.pi) /(2*wt)) * ((Z_lamb_s_4 * (1-(rl/R))) + (2 * Z_lamb_s_2 *(1-(rl/Z_lamb_s_2)**2)))
g1=((alpha*R)/(Z_lamb_s_4**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+(((2)*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4


BW=(k0/2)*((1/G0)**((1/4)))


BW_MHz=BW * 10**(-6)
BWteste1 = BW_MHz
BWteste1[G0 < 18] = 0
BWteste1[BW_MHz < 300]=0
BWteste1[BW_MHz > 1000]=0

# %%
#gráfico2
plt.contourf(Z_lamb_s_4,Z_lamb_s_2, BWteste1,cmap='hot')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center', fontsize=20)
ticklabs = clb.ax.get_yticklabels()
clb.ax.set_yticklabels(ticklabs, fontsize=15)
plt.title(r'$C_p$ = 2,5 pF', fontsize=20)
#plt.plot(40, 60, "o")
plt.ylabel(r'$Z_{\lambda/2}$ [$\Omega$]', fontsize=20)
plt.xlabel(r'$Z_{\lambda/4}$ [$\Omega$]', fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# # outro tipo para aqui

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores pra wd=0
X = np.linspace(20, 70, 1000)
Y2 = np.linspace(20,75,1000)
#f = np.linspace(5.4,5.6,1000) *(10**9)
x, y2 = np.meshgrid(X, Y2)
y2 = np.flip(y2)
#x=30
#y=3 * 10**(-12)

#omg=(0.01*(10**9))
wt=(6 * 10**(9)) #Hz
omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
R=50 #ohms
#y=58 #Ohms
y= 2.5 * (10**(-12))
phi0=2.06783*(10**(-15))
Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap = (8 * 10**(9))
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))



k0=1/(R * 2 * y)
wd=(omegap-wt)* 2 * (np.pi) #
#beta=0.42
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)
rl=(x**2)/R
alpha=((np.pi) /(2*wt)) * ((x * (1-(rl/R))) + (2 * y2 *(1-(rl/y2)**2)))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+((2*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4
#print(G0)
BW=(k0/2)*((G0)**(-0.25))
#ganho=Gmax/((1+(omg/BW))**4)
#print('k0=', '{:e}'.format(k0))
#print('g1=', '{:e}'.format(g1))
#print('alpha=', '{:e}'.format(alpha))
#print('beta', '{:e}'.format(beta))
#print('lamb=', '{:e}'.format(lamb))
#print('G0=', '{:e}'.format(G0))
#print('Gmax=', '{:e}'.format(Gmax))

BW_MHz=BW * 10**(-6)

BWteste = BW_MHz
BWteste[G0 < 18] = 0
BWteste[BW_MHz < 300]=0
#BWteste[BW_MHz > 1000]=0

#gráfico

plt.contourf(x, y2, BWteste,cmap='hot')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center')
plt.title(r'$C_p$ = 2,5 pF')
plt.plot(38, 60, "o")
plt.ylabel(r'$Z_{\lambda/2}$ [$\Omega$]')
plt.xlabel(r'$Z_{\lambda/4}$ [$\Omega$]')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(5.5,6.5,1000) *(10**9)
x=40 #Ohms
y=2.5 * 10**(-12)


wt=(6 * 10**(9)) #Hz
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=2*(10**(-6))
lp=phi0/(2*(np.pi)*Ic)

zp=np.sqrt(lp/y)

#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))
#k0=R/((x**2)*y) #1.5e10
k02=1/(R * 2 * y)
k01=omegap*zp/R

wd=(omegap-wt)* 2 * (np.pi) #

beta1=(2*wd)/((np.sqrt(3))*k01)
beta2= (2 * wd)/((np.sqrt(3)) * (k02))
lamb= (k02 * (1 + (3 * beta2**2))**0.5)/(12**0.5)
rl=(x**2)/R
G01=1+(3*(1+(7*beta1**2)-(4*beta1*(np.sqrt(1+(3*beta1**2))))))**(-1)
G02=1+(((4*k02*lamb)**2)/((k02**2-4*(lamb**2-wd**2))**2))


f_opt=5.8*(10**9)
omegap_opt=2*np.pi*f_opt
wd_opt=(f_opt-wt)*2*np.pi

k00=omegap_opt*zp/R
beta3=(2*wd_opt)/((np.sqrt(3))*k00)
ni=(wd_opt/omegap_opt)*((1+(1.4142*(np.sqrt(1+(3*beta3**2)-(2*beta3*(np.sqrt(1+(3*beta3**2))))))))**(-1))
Zopt=ni*2500/zp

print('Zopt=', Zopt)
BW1=(k01/2)*((1/G01)**((1/2)))
BW2=(k02/2)*((1/G02)**((1/4)))
#BW1[G01<15]=0

ganho1=G01/(1+(wd/BW1)**2)
ganho2=G02/(1+(wd/BW2)**4)


#BW1_MHz=BW * 10**(-6)
#BWteste = BW_MHz
#BWteste[G0 < 18] = 0
#BWteste[f<wt]=0
#BWteste[BW_MHz < 300]=0
#BWteste[BW_MHz > 900]=0

ganho1_dB = 10 * np.log10(ganho1)
ganho2_dB = 10 * np.log10(ganho2)


#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz, ganho1_dB, label = 'Sem CPW')
#plt.semilogy()
plt.ylabel('Ganho [dB]')
plt.xlabel(r'$Frequência$ [GHz]')
#plt.axhline(y=500, linestyle='--')
f_GHz=f * (10**(-9))
plt.plot(f_GHz, ganho2_dB, label = 'Com CPW')
#plt.semilogy()
plt.ylabel('Ganho [dB]')
plt.xlabel('Frequência [GHz]')
plt.legend()
plt.show()
# Out:
# Zopt= -3.7264672568778545

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show





f = np.linspace(5,100,1000) *(10**9)

Z=9.06*(10**6)/(1+(4*(7.66*(10**(-11)))*(f-(4.062*(10**10)))**2))



#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz, Z,)
#plt.semilogy()
plt.ylabel('Impedância')
plt.xlabel(r'$Frequência$ [GHz]')
# Out:
# Text(0.5, 0, '$Frequência$ [GHz]')

# %%
import numpy as np

x=40 #lamb/4
y=58 #lamb/2
R=50
Zaux=(np.pi/4)*((x*(1-((x/R)**2)))+(2*y*(1-((x/(y*R))**2))))
print(Zaux)
# Out:
# 102.39858758204194

# %%
np.pi/4
# Out:
# 0.7853981633974483

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
f = np.linspace(1,20,10000) *(10**9)
x=40 #Ohms
y=2.5 * 10**(-12)


wt=(6.1 * 10**(9)) #Hz
#omegap= (6.95 * 10**9) #varia de 5-7.25 GHz
omegap=f
R=50 #ohms
y2=60 #Ohms
phi0=2.06783*(10**(-15))
Ic=2*(10**(-6))
lp=phi0/(2*(np.pi)*Ic)

zp=np.sqrt(lp/y)





#f_opt=5.8*(10**9)
omegap_opt=2*np.pi*f
wd_opt=(f-wt)*2*np.pi

k00=omegap_opt*zp/R
beta3=(2*wd_opt)/((np.sqrt(3))*k00)
ni=(wd_opt/omegap_opt)*((1+(1.4142*(np.sqrt(1+(3*beta3**2)-(2*beta3*(np.sqrt(1+(3*beta3**2))))))))**(-1))
Zopt=ni*(R**2)/zp

#gráfico
f_GHz=f * (10**(-9))
plt.plot(f_GHz, Zopt,)
#plt.semilogy()
plt.ylabel('Impedância')
plt.xlabel(r'$Frequência$ [GHz]')
# Out:
# C:\Users\molin\AppData\Local\Temp\ipykernel_24856\1816827505.py:47: RuntimeWarning: invalid value encountered in sqrt
#   ni=(wd_opt/omegap_opt)*((1+(1.4142*(np.sqrt(1+(3*beta3**2)-(2*beta3*(np.sqrt(1+(3*beta3**2))))))))**(-1))
# Text(0.5, 0, '$Frequência$ [GHz]')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show


phi0=1
Ic=2
I0=0
I1=Ic/2

phi=np.linspace(0,(5*(np.pi)),100)

U0=(phi0*Ic/(2*np.pi))*(1-(np.cos(phi))-(I0*phi/Ic))
U1=(phi0*Ic/(2*np.pi))*(1-(np.cos(phi))-(I1*phi/Ic))
Uc=(phi0*Ic/(2*np.pi))*(1-(np.cos(phi))-(Ic*phi/Ic))


#gráfico
plt.plot(phi, U0)
plt.ylabel(r'$U(\phi)$')
plt.xlabel(r'$Fase\phi$')

plt.plot(phi, U1)
plt.ylabel(r'$U(\phi)$')
plt.xlabel(r'$Fase\phi$')
plt.grid()
plt.plot(phi, Uc)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.ylabel(r'$U(\phi)$')
plt.xlabel(r'$Fase\phi$')
# Out:
# Text(0.5, 0, '$Fase\\phi$')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show


i1=np.linspace(-5,5,1000)*(10**-6)
Ic1=3.6*(10**(-6))
i2=np.linspace(-5,5,1000)*(10**-6)
Ic2=-3.6*(10**(-6))


Rj=200 #Ohms
V1=Ic1*Rj*(np.sqrt((i1/Ic1)**2-1))
V2=Ic2*Rj*(np.sqrt((i2/Ic2)**2-1))

for j in range(0,len(i1)):
    if (i1[j]<Ic1) and (i1[j]>0):
        V1[j]=0
        
for j in range(0,len(i2)):
    if (i2[j]<Ic2) and (i2[j]>0):
        V2[j]=0

plt.plot(i1, V2)
plt.plot(i2, V2)
plt.ylabel(r'$Tensão [V]$')
plt.xlabel(r'$Corrente [A]$')
# Out:
# C:\Users\molin\AppData\Local\Temp\ipykernel_24856\616140453.py:17: RuntimeWarning: invalid value encountered in sqrt
#   V1=Ic1*Rj*(np.sqrt((i1/Ic1)**2-1))
# C:\Users\molin\AppData\Local\Temp\ipykernel_24856\616140453.py:18: RuntimeWarning: invalid value encountered in sqrt
#   V2=Ic2*Rj*(np.sqrt((i2/Ic2)**2-1))
# Text(0.5, 0, '$Corrente [A]$')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show


phi=np.linspace(0,2,100)
phi0=1

Ic1=0.5
Ic1_total=2*Ic1*np.abs(np.cos(np.pi*(phi/phi0)))

I11=0.4
I21=0.6

Ic2_total=np.sqrt((I11-I21)**2+(4*I11*I21*(np.cos(np.pi*(phi/phi0)))**2))

I12=0.3
I22=0.7

Ic3_total=np.sqrt((I12-I22)**2+(4*I12*I22*(np.cos(np.pi*(phi/phi0)))**2))

I13=0.1
I23=0.9

Ic4_total=np.sqrt((I13-I23)**2+(4*I13*I23*(np.cos(np.pi*(phi/phi0)))**2))


plt.plot(phi, Ic1_total, label='Ic1=Ic2= 1A')
plt.plot(phi, Ic2_total, label='Ic1= 0.4A; Ic2= 0.6A')
plt.plot(phi, Ic3_total, label='Ic1= 0.3A; Ic2= 0.7A')
plt.plot(phi, Ic4_total, label='Ic1= 0.1A; Ic2= 0.9A')
plt.ylabel('Corrente Crítica SQUID [A]')
plt.xlabel('Fluxo Magnético ' r'$\Phi [\Phi_0]$')
plt.legend()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp2d
import numpy as np
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

#x=Cp
#y=Zlamb/4
#y2=Zlamb/2
#R=chain impedance
#Ic=corrente crítica JJ
#wt=freq do CPW de modelo
#wp=freq detuning
#phi0= quantum flux
#omega_p=transmon freq


#dados geradores
##gráfico 1
X = np.linspace(30, 45, 1000)
Y = np.linspace(1,5,1000) * (10**(-12))
x, y = np.meshgrid(X, Y)
y = np.flip(y)

#constantes gráfico 1
wt=(6.8 * 10**(9)) * 2 *np.pi #Hz
#omegap= wt+(0.01 * 10**9) #varia de 5-7.25 GHz
omegap=(7.5 * 10**(9)) * 2 *np.pi
R=50 #ohms
lamb2=60 #Ohms
phi0=2.06783*(10**(-15))
#Ic=3.6*(10**(-6))
#wp=2 * wt
#omegap=np.sqrt((2 * (np.pi) * Ic)/(phi0 * y))


#cálculo gráfico 1
k0=1/(R * 2 * y)
#wd=0.01*(10**9)
wd=(omegap-wt)
#print(wd)
rl=(x**2)/R
beta= (2 * wd)/((np.sqrt(3)) * (k0))
lamb= (k0 * (1 + (3 * beta**2))**0.5)/(12**0.5)



alpha=((np.pi) /(2*wt)) * ((x * (1-(rl/R)**2)) + (2 * lamb2 *(1-(rl/lamb2)**2)))
g1=((alpha*R)/(x**2))-(k0/(2*(lamb**2-wd**2)))
G0=1+(((2)*((k0 * lamb)**0.5))/(2 * g1*(lamb**2 - wd**2)))**4


BW=(k0/2)*((1/G0)**((1/4)))


BW_MHz=BW * 10**(-6)
BWteste = BW_MHz
BWteste[G0 < 18] = 0
BWteste[BW_MHz < 300]=0
BWteste[BW_MHz > 1000]=0

cp=2.8*(10**(-12))
#gráficos
#grafico1
plt.contourf(x, y, BWteste,cmap='hot')
clb = plt.colorbar()
clb.set_label('Largura de Banda [MHz]', y=0.5, ha='center')
plt.title(r'$Z_{\lambda/2}$ = 60 $\Omega$')
plt.ylabel(r'$C_p$ [pF]')
plt.xlabel(r'$Z_{\lambda/4}$')
plt.plot(33.33, (cp), "-o")
plt.show()

# %%
algo=(0.00782406*(1.380649*(10**-23))/(299792458))
print(algo)
# Out:
# 3.6032529593989996e-34
