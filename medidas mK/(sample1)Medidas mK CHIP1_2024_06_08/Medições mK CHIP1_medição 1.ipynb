# %% [markdown]
# # MEDIÇÃO SAMPLE1 - CHIP1 COM 4 RESSONADORES

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import numpy as np
import pandas as pd
import csv
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from collections import Counter
from scipy import interpolate
from scipy.optimize import leastsq
from scipy import stats
import copy
from io import StringIO
from MyFunctions import * # MyModule
from scipy.optimize import curve_fit

# %% [markdown]
# # CHIP1 COMPLETO

# %%
S21_freq_1to10GHz, S21_1to10GHz = ImportS3P("C:/Users/molin/medidas mK/(sample1)Medidas mK CHIP1_2024_06_08/S21_chip1_1-10GHz_span_finer.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(S21_freq_1to10GHz, S21_1to10GHz, linewidth=2, color='black')
ax.set_title("S21 CHIP1 Completo $S_{21}$", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=28)
ax.set_ylabel(r"Transmissão (dB)", fontsize=28)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.set_xlim(3,4)

# %% [markdown]
# # Ressonador 1 - $\lambda/4$

# %%
S21_freq_res1, S21_res1 = ImportS3P("C:/Users/molin/medidas mK/(sample1)Medidas mK CHIP1_2024_06_08/S21_chip1_2.075-2.125GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)

# %%
S21_freq_chip1_res1_simu,S21_chip1_res1_simu = ImportS3P("C:/Users/molin/medidas mK/chip1_ressonadores_simulações/ANSYS/chip1_res1.csv", 
                                     Delimiter = ",", Skip_head=1, Cols = (0,1))

# %%
print(np.max(S21_res1))
# Out:
# -28.81557859

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,10))

ax[0].plot(S21_freq_res1, S21_res1+28.81557859, linewidth=2, color='black', label='Dados')
ax[0].set_title("$S_{21}$ Ressonador 1 - Dados", fontsize=32)
ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax[0].set_ylabel(r"Transmissão (dB)", fontsize=32)
ax[0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[0].set_xlim(2.08,2.12)

ax[1].plot(S21_freq_chip1_res1_simu,S21_chip1_res1_simu, linewidth=2, color = 'red')
ax[1].set_title("$S_{21}$ Ressonador 1 - Simulação", fontsize=32)
ax[1].set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax[1].set_ylabel(r"Transmissão (dB)", fontsize=32)
ax[1].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[1].set_xlim(2.8,2.9)
ax[1].set_ylim(-15,1)
# Out:
# (-15.0, 1.0)

# %%
c=10*(log10(20))
#S21_res1_amp_l=(pow(10,20/(S21_res1-c)))*1000
S21_res1_amp_l=20*(10**((S21_res1/10)))

S21_res2_amp_l=(pow(10,(S21_res2-c)/20))*1000
S21_res3_amp_l=(pow(10,(S21_res3-c)/20))*1000
S21_res4_amp_l=(pow(10,(S21_res4-c)/20))*1000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 5
#       2 #S21_res1_amp_l=(pow(10,20/(S21_res1-c)))*1000
#       3 S21_res1_amp_l=20*(10**((S21_res1/10)))
# ----> 5 S21_res2_amp_l=(pow(10,(S21_res2-c)/20))*1000
#       6 S21_res3_amp_l=(pow(10,(S21_res3-c)/20))*1000
#       7 S21_res4_amp_l=(pow(10,(S21_res4-c)/20))*1000
#
# NameError: name 'S21_res2' is not defined

# %%
fig, ax = plt.subplots(1, 1, figsize=(15,10))

ax.plot(S21_freq_res4,S21_res4_amp_l)
ax.plot(S21_freq_res4[1500:8500],S21_res4_amp_l[1500:8500]-2.2)
ax.set_xlabel(r"Frequência (GHz)", fontsize=30)
ax.set_ylabel(r"$S_{21}$ (mV)", fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=28)
ax.set_title("$S_{21}$ Ressonador 1 - Volts", fontsize=32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 fig, ax = plt.subplots(1, 1, figsize=(15,10))
# ----> 3 ax.plot(S21_freq_res4,S21_res4_amp_l)
#       4 ax.plot(S21_freq_res4[1500:8500],S21_res4_amp_l[1500:8500]-2.2)
#       5 ax.set_xlabel(r"Frequência (GHz)", fontsize=30)
#
# NameError: name 'S21_freq_res4' is not defined

# %% [markdown]
# # Ressonador 2 - $\lambda/4$

# %%
S21_freq_chip1_res2_simu,S21_chip1_res2_simu = ImportS3P("C:/Users/molin/medidas mK/chip1_ressonadores_simulações/ANSYS/chip1_res2.csv", 
                                     Delimiter = ",", Skip_head=1, Cols = (0,1))

# %%
S21_freq_res2,S21_res2 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/S21_chip1_3.21-3.24GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 S21_freq_res2,S21_res2 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/S21_chip1_3.21-3.24GHz_span.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
print(np.max(S21_res2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 print(np.max(S21_res2))
#
# NameError: name 'S21_res2' is not defined

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,10))

ax[0].plot(S21_freq_res2, S21_res2+14.49070799, linewidth=2, color='black', label='Dados')
ax[0].set_title("$S_{21}$ Ressonador 2 - Dados", fontsize=32)
ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[0].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
#ax[0].set_xlim(2.08,2.12)

ax[1].plot(S21_freq_chip1_res2_simu,S21_chip1_res2_simu, linewidth=2, color = 'red')
ax[1].set_title("$S_{21}$ Ressonador 2 - Simulação", fontsize=32)
ax[1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[1].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[1].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[1].set_xlim(4.5,4.65)
#ax[1].set_ylim(-15,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 3
#       1 fig, ax = plt.subplots(1, 2, figsize=(25,10))
# ----> 3 ax[0].plot(S21_freq_res2, S21_res2+14.49070799, linewidth=2, color='black', label='Dados')
#       4 ax[0].set_title("$S_{21}$ Ressonador 2 - Dados", fontsize=32)
#       5 ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
#
# NameError: name 'S21_freq_res2' is not defined

# %% [markdown]
# # Ressonador 3 - $\lambda/2$

# %%
S21_freq_chip1_res3_simu,S21_chip1_res3_simu = ImportS3P("C:/Users/molin/medidas mK/chip1_ressonadores_simulações/ANSYS/chip1_res3.csv", 
                                     Delimiter = ",", Skip_head=1, Cols = (0,1))

# %%
S21_freq_res3,S21_res3 = ImportS3P("C:/Users/molin/medidas mK/(sample1)Medidas mK CHIP1_2024_06_08/S21_chip1_6.235-6.255GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)

# %%
print(np.max(S21_res3))
# Out:
# -24.94027078

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,10))

ax[0].plot(S21_freq_res3, S21_res3+31.94027078, linewidth=2, color='black', label='Dados')
#ax[0].set_title("$S_{21}$ Ressonador 3 - Dados", fontsize=32)
ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[0].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
#ax[0].set_xlim(6.235,6.250)
ax[0].set_ylim(-15,0)
#ax[0].set_xticklabels(np.arange(6.235,6.250,10))

ax[1].plot(S21_freq_chip1_res3_simu,S21_chip1_res3_simu, linewidth=2, color = 'red')
#ax[1].set_title("$S_{21}$ Ressonador 3 - Simulação", fontsize=32)
ax[1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[1].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[1].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[1].set_xlim(6.3,6.45)
ax[1].set_ylim(-25,0)
# Out:
# (-25.0, 0.0)

# %% [markdown]
# # Ressonador 4 - $\lambda/2$

# %%
S21_freq_chip1_res4_simu,S21_chip1_res4_simu = ImportS3P("C:/Users/molin/medidas mK/chip1_ressonadores_simulações/ANSYS/chip1_res4.csv", 
                                     Delimiter = ",", Skip_head=1, Cols = (0,1))

# %%
S21_freq_res4,S21_res4 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/S21_chip1_8.26-8.285GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 S21_freq_res4,S21_res4 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/S21_chip1_8.26-8.285GHz_span.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
print(np.max(S21_res4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print(np.max(S21_res4))
#
# NameError: name 'S21_res4' is not defined

# %%
fig, ax = plt.subplots(1, 2, figsize=(25,10))

ax[0].plot(S21_freq_res4, S21_res4+40.21047239, linewidth=2, color='black', label='Dados')
ax[0].set_title("$S_{21}$ Ressonador 4 - Dados", fontsize=32)
ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[0].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
#ax[0].set_xlim(6.235,6.250)

ax[1].plot(S21_freq_chip1_res4_simu,S21_chip1_res4_simu, linewidth=2, color = 'red')
ax[1].set_title("$S_{21}$ Ressonador 4 - Simulação", fontsize=32)
ax[1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[1].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[1].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[1].set_xlim(8.4,8.6)
#ax[1].set_ylim(-25,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 3
#       1 fig, ax = plt.subplots(1, 2, figsize=(25,10))
# ----> 3 ax[0].plot(S21_freq_res4, S21_res4+40.21047239, linewidth=2, color='black', label='Dados')
#       4 ax[0].set_title("$S_{21}$ Ressonador 4 - Dados", fontsize=32)
#       5 ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
#
# NameError: name 'S21_freq_res4' is not defined

# %%
fig, ax = plt.subplots(2, 2, figsize=(29,25))

ax[0,0].plot(S21_freq_res1, S21_res1+28.81557859, linewidth=2, color='black', label='Dados')
ax[0,0].set_title("$S_{21}$ Ressonador 1", fontsize=32)
ax[0,0].set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax[0,0].set_ylabel(r"Transmissão (dB)", fontsize=32)
ax[0,0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
ax[0,0].set_xlim(2.08,2.12)

ax[0,1].plot(S21_freq_res2, S21_res2+14.49070799, linewidth=2, color='black', label='Dados')
ax[0,1].set_title("$S_{21}$ Ressonador 2", fontsize=32)
ax[0,1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[0,1].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[0,1].tick_params(axis='both', which='major', labelsize=28)


ax[1,0].plot(S21_freq_res3, S21_res3+31.94027078, linewidth=2, color='black', label='Dados')
ax[1,0].set_title("$S_{21}$ Ressonador 3", fontsize=32)
ax[1,0].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[1,0].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[1,0].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
#ax[0].set_xlim(6.235,6.250)
ax[1,0].set_ylim(-15,0)

ax[1,1].plot(S21_freq_res4, S21_res4+40.21047239, linewidth=2, color='black', label='Dados')
ax[1,1].set_title("$S_{21}$ Ressonador 4", fontsize=32)
ax[1,1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
ax[1,1].set_ylabel(r"Transmissão (dB)", fontsize=35)
ax[1,1].tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='lower right', prop={'size': 25})
#ax[0].set_xlim(6.235,6.250)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 11
#       8 #ax.legend(loc='lower right', prop={'size': 25})
#       9 ax[0,0].set_xlim(2.08,2.12)
# ---> 11 ax[0,1].plot(S21_freq_res2, S21_res2+14.49070799, linewidth=2, color='black', label='Dados')
#      12 ax[0,1].set_title("$S_{21}$ Ressonador 2", fontsize=32)
#      13 ax[0,1].set_xlabel(r"Frequencia (GHz)", fontsize=35)
#
# NameError: name 'S21_freq_res2' is not defined

# %% [markdown]
# # MEDIÇÕES DA FASE

# %% [markdown]
# # FASE RESSONADOR 1

# %%
fase_freq_res1,fase_res1 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_2.08-2.12GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 fase_freq_res1,fase_res1 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_2.08-2.12GHz_span.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_res1,fase_res1, linewidth=2, color='black', label='Dados')
ax.set_title("Fase Ressonador1 CHIP 1", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (Graus)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(8.2,8.7)
#ax.set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 3
#       1 fig, ax = plt.subplots(1, 1, figsize=(16,10))
# ----> 3 ax.plot(fase_freq_res1,fase_res1, linewidth=2, color='black', label='Dados')
#       4 ax.set_title("Fase Ressonador1 CHIP 1", fontsize=25)
#       5 ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res1' is not defined

# %% [markdown]
# # FASE RESSONADOR 2

# %%
fase_freq_res2,fase_res2 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_3.2-3.25GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 fase_freq_res2,fase_res2 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_3.2-3.25GHz_span.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_res2,fase_res2, color='black',linewidth=2, label='Dados')
ax.set_title("Fase Ressonador2 CHIP 1", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (Graus)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(3.21,3.235)
#ax.set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 fig, ax = plt.subplots(1, 1, figsize=(16,10))
# ----> 3 ax.plot(fase_freq_res2,fase_res2, color='black',linewidth=2, label='Dados')
#       4 ax.set_title("Fase Ressonador2 CHIP 1", fontsize=25)
#       5 ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res2' is not defined

# %% [markdown]
# # FASE RESSONADOR 3

# %%
fase_freq_res3,fase_res3 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_6.215-6.275GHz_span.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 fase_freq_res3,fase_res3 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_6.215-6.275GHz_span.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_res3,fase_res3, color='black',linewidth=2, label='Dados')
ax.set_title("Fase Ressonador3 CHIP 1", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (Graus)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(6.235,6.255)
#ax.set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 fig, ax = plt.subplots(1, 1, figsize=(16,10))
# ----> 3 ax.plot(fase_freq_res3,fase_res3, color='black',linewidth=2, label='Dados')
#       4 ax.set_title("Fase Ressonador3 CHIP 1", fontsize=25)
#       5 ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res3' is not defined

# %%
#Unwrap phase
#fase_res3_wrap=fase_res3[2000:4500]
#fase_freq_res3_wrap = fase_freq_res3[2000:4500]
#fase_res3__wrap_l=unwrap_d((fase_freq_res3_wrap))

fase_res3_l=np.unwrap(radians(fase_res3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 6
#       1 #Unwrap phase
#       2 #fase_res3_wrap=fase_res3[2000:4500]
#       3 #fase_freq_res3_wrap = fase_freq_res3[2000:4500]
#       4 #fase_res3__wrap_l=unwrap_d((fase_freq_res3_wrap))
# ----> 6 fase_res3_l=np.unwrap(radians(fase_res3))
#
# NameError: name 'fase_res3' is not defined

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,8))

ax[0].plot(fase_freq_res3,fase_res3, color='black',linewidth=2, label='Dados')
ax[0].set_title("Fase Ressonador2 CHIP 1", fontsize=25)
ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax[0].set_ylabel(r"Fase (Graus)", fontsize=32)
ax[0].tick_params(axis='both', which='major', labelsize=20)
#ax[0].legend(loc='upper right', prop={'size': 25})
#ax[0].set_xlim(6.235,6.255)
#ax[0].set_ylim(-50,0)

ax[1].plot(fase_freq_res3,fase_res3_l, color='black',linewidth=2, label='Dados')
ax[1].set_title("Fase Ressonador2 CHIP 1", fontsize=25)
ax[1].set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax[1].set_ylabel(r"Fase (rad)", fontsize=32)
ax[1].tick_params(axis='both', which='major', labelsize=15)
#ax[1].legend(loc='upper right', prop={'size': 25})
#ax[1].set_xlim(6.235,6.255)
#ax[1].set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 fig, ax = plt.subplots(1, 2, figsize=(20,8))
# ----> 3 ax[0].plot(fase_freq_res3,fase_res3, color='black',linewidth=2, label='Dados')
#       4 ax[0].set_title("Fase Ressonador2 CHIP 1", fontsize=25)
#       5 ax[0].set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res3' is not defined

# %% [markdown]
# # FASE RESSONADOR 4

# %%
fase_freq_res4,fase_res4 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_8.25-8.3GHz_span_2.txt"\
                                       ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fase_freq_res4,fase_res4 = ImportS3P("C:/Users/molin/medidas mK/Medidas mK CHIP1_2024_06_08/Fase/Fase_chip1_8.25-8.3GHz_span_2.txt"\
#       2                                        ,Delimiter = "\t", Cols = (0,1), Skip_head=0)
#
# File ~\medidas mK\(sample1)Medidas mK CHIP1_2024_06_08\MyFunctions.py:227, in ImportS3P(file_name, Cols, Skip_head, Delimiter)
#     222 def ImportS3P(file_name, Cols=(0, 3), Skip_head = 0, Delimiter = " "):
#     223     """  Import from s2p file freq, S21 - Amp and Phase, Return Freq, S21_Amp and S21
#     224          sometimes need to use
#     225          np.genfromtxt(path, delimiter=("\t"), skip_header=5, usecols=(0,3,4),dtype=None)#,invalid_raise = False)
#     226     """
# --> 227     data = genfromtxt(file_name, delimiter=(
# ...

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_res4,fase_res4, color='black',linewidth=2, label='Dados')
ax.set_title("Fase Ressonador4 CHIP 1", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (Graus)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(8.26,8.28)
#ax.set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 fig, ax = plt.subplots(1, 1, figsize=(16,10))
# ----> 3 ax.plot(fase_freq_res4,fase_res4, color='black',linewidth=2, label='Dados')
#       4 ax.set_title("Fase Ressonador4 CHIP 1", fontsize=25)
#       5 ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res4' is not defined

# %%
fase_freq_fundo_GHz,nun,fase_fundo = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span18GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)

# %%
fase_freq_fundo=fase_freq_fundo_GHz/(10**9)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_fundo,fase_fundo, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res3,fase_res3, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (Graus)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(6.21,6.28)
#ax.set_ylim(-50,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 4
#       1 fig, ax = plt.subplots(1, 1, figsize=(16,10))
#       3 ax.plot(fase_freq_fundo,fase_fundo, color='black',linewidth=2, label='Fundo')
# ----> 4 ax.plot(fase_freq_res3,fase_res3, color='red')
#       5 ax.set_title("Fase Fundo", fontsize=25)
#       6 ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#
# NameError: name 'fase_freq_res3' is not defined

# %% [markdown]
# # CORREÇÃO FASE DO FUNDO

# %% [markdown]
# ## Ressonador 1

# %%
fase_fundo_l=unwrap(radians(fase_fundo))
fase_res1_l=unwrap(radians(fase_res1))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+1100, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res1,fase_res1_l, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(2.09,2.105)
#ax.set_ylim(-100,100)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_fundo,fase_fundo_l+2000, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res1,fase_res1_l, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(2.05,2.15)
#ax.set_ylim(-500,10)

# %%
fase_fundo_l_fit=interp1d(fase_freq_fundo,fase_fundo_l, kind='cubic')

# %%
fase_res1_l_fit=wrap1(fase_fundo_l_fit(fase_freq_res1)-fase_res1_l)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+1100, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res1,fase_res1_l_fit, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(2.09,2.105)
#ax.set_ylim(-50,50)

# %% [markdown]
# ## Rodar os dados

# %%
print(len(S21_res1[1500:8500])), print(len(fase_res1_l_fit))

# %%
S21_res1_amp_l_7k=S21_res1_amp_l[1500:8500]

# %%
from scipy import odr

# importando dado
X0=S21_freq_res1
Y0=(S21_res1_amp_l_7k * (exp(1j * fase_res1_l_fit)))* (exp(1j * np.pi))

x = Y0.real
y = Y0.imag

x_m=mean(x)
y_m=mean(y)

def calc_R(xc, yc):
    """ calculate the distance of each 2D points from the center (xc, yc) """
    return sqrt((x-xc)**2 + (y-yc)**2)

def f_3(beta, x):
    """ implicit definition of the circle """
    return (x[0]-beta[0])**2 + (x[1]-beta[1])**2 -beta[2]**2


# initial guess for parameters
R_m = calc_R(x_m, y_m).mean()
beta0 = [ x_m, y_m, R_m]

d = sqrt((x-x_m)**2+(y-y_m)**2)
error = R_m/sqrt(mean((d-R_m)**2))
# print(error)


# for implicit function :
#       data.x contains both coordinates of the points (data.x = [x, y])
#       data.y is the dimensionality of the response
lsc_data  = odr.Data(row_stack([x, y]),y=1)#,we=1/error,wd=error)
lsc_model = odr.Model(f_3, implicit=True)
lsc_odr   = odr.ODR(lsc_data, lsc_model, beta0)
lsc_out   = lsc_odr.run()

xc_3, yc_3, R_3 = lsc_out.beta
Ri_3 = calc_R(xc_3, yc_3)
residu_3 = sum((Ri_3 - R_3)**2)
lsc_out.beta

# %%
x0 = lsc_out.beta[0]
y0 = lsc_out.beta[1]
r0 = lsc_out.beta[2]


a = linspace(0,2*pi,1000)
x = r0 + r0 *cos(a)
y =  r0 *sin(a)
print(x0,y0,r0)

plt.plot(x,y,'g-')
plt.plot(Y0.real,Y0.imag,'ro')
Angle = arctan2(y0,x0)
print(Angle)
Y1=(Y0-complex(x0,y0))*exp(1j*Angle)+sqrt(x0**2+y0**2)
# Y1=(Y0)*exp(1j*Angle)

plt.plot(Y1.real,Y1.imag,'kv')
# plot(Fit.real,Fit.imag,'go')
plt.hlines(0,min(Y1.real),max(Y1.real))
plt.vlines(0,min(Y1.imag),max(Y1.imag))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(S21_freq_res1[1500:8500], 20*log10(abs(Y1)), color='blue')
ax.plot(fase_freq_res1, angle(Y1), color='red')
ax.plot(fase_freq_res1,fase_res1_l_fit, color='black')
#ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(2.096,2.101)
#ax.set_ylim(-50,50)

# %% [markdown]
# ## Ressonador 2

# %%
fase_freq_fundo,nun,fase_fundo = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span18GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)

# %%
fase_fundo_l=unwrap(radians(fase_fundo))
fase_res2_l=unwrap(radians(fase_res2))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+1650, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res2,fase_res3_l, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(3.21,3.235)
ax.set_ylim(-50,50)

# %%
fase_fundo_l_fit=interp1d(fase_freq_fundo,fase_fundo_l, kind='cubic')

# %%
fase_res2_l_fit=wrap1(fase_fundo_l_fit(fase_freq_res2*(10**9))-fase_res2_l)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+1100, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res2,fase_res2_l_fit, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(2.09,2.105)
#ax.set_ylim(-50,50)

# %% [markdown]
# ## Ressonador 3

# %%
fase_freq_fundo,nun,fase_fundo = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span6GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)

# %%
fase_fundo_l=unwrap(radians(fase_fundo))
fase_res3_l=unwrap(radians(fase_res3))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+3160, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res3,fase_res3_l, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(6.21,6.28)
ax.set_ylim(-100,100)

# %% [markdown]
# # INTERPOLAÇÃO

# %%
fase_fundo_l_fit=interp1d(fase_freq_fundo,fase_fundo_l, kind='cubic')

# %% [markdown]
# ## CORREÇÃO DOS DADOS

# %%
fase_res3_l_fit=wrap1(fase_fundo_l_fit(fase_freq_res3*(10**9))-fase_res3_l)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+3150, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res3,fase_res3_l_fit, color='red')
ax.set_title("Fase Ressonador 3 Corrigida", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (radianos)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(6.215,6.26)
#ax.set_ylim(-100,100)

# %% [markdown]
# ## Ressonador 4

# %%
fase_freq_fundo,nun,fase_fundo = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span6GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)

# %%
fase_fundo_l=unwrap(radians(fase_fundo))
fase_res4_l=unwrap(radians(fase_res4))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+2200, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res4,fase_res4_l, color='red')
ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
ax.set_xlim(8.26,8.28)
ax.set_ylim(-70,70)

# %%
fase_fundo_l_fit=interp1d(fase_freq_fundo,fase_fundo_l, kind='cubic')

# %%
fase_res4_l_fit=wrap1(fase_fundo_l_fit(fase_freq_res4*(10**9))-fase_res4_l)

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+3150, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res4,fase_res4_l_fit, color='red')
ax.set_title("Fase Ressonador 4 Corrigida", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
ax.set_ylabel(r"Fase (radianos)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(8.26,8.28)
#ax.set_ylim(-100,100)

# %%
print(len(S21_res4))
S21_res4_amp_l_7k=S21_res4[1500:8500]

# %%
from scipy import odr

# importando dado
X0=S21_freq_res4
Y0=(S21_res4_amp_l_7k * (exp(1j * fase_res4_l_fit))) * (exp(1j * np.pi))

x = Y0.real
y = Y0.imag

x_m=mean(x)
y_m=mean(y)

def calc_R(xc, yc):
    """ calculate the distance of each 2D points from the center (xc, yc) """
    return sqrt((x-xc)**2 + (y-yc)**2)

def f_3(beta, x):
    """ implicit definition of the circle """
    return (x[0]-beta[0])**2 + (x[1]-beta[1])**2 -beta[2]**2


# initial guess for parameters
R_m = calc_R(x_m, y_m).mean()
beta0 = [ x_m, y_m, R_m]

d = sqrt((x-x_m)**2+(y-y_m)**2)
error = R_m/sqrt(mean((d-R_m)**2))
# print(error)


# for implicit function :
#       data.x contains both coordinates of the points (data.x = [x, y])
#       data.y is the dimensionality of the response
lsc_data  = odr.Data(row_stack([x, y]),y=1)#,we=1/error,wd=error)
lsc_model = odr.Model(f_3, implicit=True)
lsc_odr   = odr.ODR(lsc_data, lsc_model, beta0)
lsc_out   = lsc_odr.run()

xc_3, yc_3, R_3 = lsc_out.beta
Ri_3 = calc_R(xc_3, yc_3)
residu_3 = sum((Ri_3 - R_3)**2)
lsc_out.beta

# %%
x0 = lsc_out.beta[0]
y0 = lsc_out.beta[1]
r0 = lsc_out.beta[2]


a = linspace(0,2*pi,1000)
x = r0 + r0 *cos(a)
y =  r0 *sin(a)
print(x0,y0,r0)

plt.plot(x,y,'g-')
plt.plot(Y0.real,Y0.imag,'ro')
Angle = arctan2(y0,x0)
print(Angle)
Y1=(Y0-complex(x0,y0))*exp(-1j*Angle)+sqrt(x0**2+y0**2)
# Y1=(Y0)*exp(1j*Angle)

plt.plot(Y1.real,Y1.imag,'kv')
# plot(Fit.real,Fit.imag,'go')
plt.hlines(0,min(Y1.real),max(Y1.real))
plt.vlines(0,min(Y1.imag),max(Y1.imag))

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,10))

#ax.plot(fase_freq_fundo/(10**9),fase_fundo_l+1100, color='black',linewidth=2, label='Fundo')
ax.plot(fase_freq_res4, angle(Y1), color='red')
ax.plot(fase_freq_res4,fase_res4_l_fit, color='black')
#ax.set_title("Fase Fundo", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=32)
#ax.set_ylabel(r"Fase (rad)", fontsize=32)
ax.tick_params(axis='both', which='major', labelsize=28)
#ax.legend(loc='upper right', prop={'size': 25})
#ax.set_xlim(8.26,8.28)
#ax.set_ylim(-50,50)
