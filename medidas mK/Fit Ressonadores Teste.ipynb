# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import numpy as np
import pandas as pd
import csv
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from collections import Counter
from scipy import interpolate
from scipy.optimize import leastsq
from scipy import stats
import copy
from io import StringIO
from MyFunctions import * # MyModule
from scipy.optimize import curve_fit

# %%
S21_freq_chip1_res3,S21_chip1_res3 = ImportS3P("C:/Users/molin/medidas mK/chip1_ressonadores_simulações/ANSYS/chip1_res3.csv", 
                                     Delimiter = ",", Skip_head=1, Cols = (0,1))

# %%
fig, ax = plt.subplots(1, 1, figsize=(12,10))

ax.plot(S21_freq_chip1_res3, (-1)*S21_chip1_res3, linewidth=3, color='blue')
ax.set_title("Simulação Ansys CHIP1 Ressonador 3", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=25)
ax.set_ylabel(r"Transmissão (dB)", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25)
ax.set_xlim(6.3,6.45)
# Out:
# (6.3, 6.45)
