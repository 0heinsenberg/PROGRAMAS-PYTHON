# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy.interpolate import interp1d
import numpy as np
import pandas as pd
import csv
import matplotlib.cm as cm
from matplotlib.colors import LogNorm
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show
from collections import Counter
from scipy import interpolate
from scipy.optimize import leastsq
from scipy import stats
import copy
from io import StringIO
from MyFunctions import * # MyModule
from scipy.optimize import curve_fit

# %% [markdown]
# # ANALISE DE DADOS PORTA AMOSTRA LUCAS ALUMINIO

# %%
#importando o fundo de 0 a 18 GHz
fundo_freq_span18GHz, fundo_amp_span18GHz, fundo_fase_span18GHz = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span18GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)
#importando o fundo de 4 a 6 GHz
fundo_freq_span2GHz, fundo_amp_span2GHz, fundo_fase_span2GHz = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span2GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)
#importando o fundo de 4 a 10 GHz
fundo_freq_span6GHz, fundo_amp_span6GHz, fundo_fase_span6GHz = ImportS2P("C:/Users/molin/medidas mK/Elsa Fundo/base_abaixo7mk_512avg_10mK_10001points_0db_linha3&4_span6GHz.csv"\
                                       ,Delimiter = ";", Cols = (0,1,2), Skip_head=0)

# %%
#import dos dados do porta amostra lucas VAZIO
freq_porta_0to4GHz, amp_porta_0to4GHz, fase_porta_0to4GHz=ImportS2P("C:/Users/molin/medidas mK/(sample2) Medidas mK CHIP1 2024_06_26/S21_span0.1_4GHz_-5dBm.csv"\
                                       ,Delimiter = " ", Cols = (0,1,2), Skip_head=1)
freq_porta_4to7GHz, amp_porta_4to7GHz, fase_porta_4to7GHz=ImportS2P("C:/Users/molin/medidas mK/(sample2) Medidas mK CHIP1 2024_06_26/S21_span4-7GHz_-5dBm.csv"\
                                       ,Delimiter = " ", Cols = (0,1,2), Skip_head=1)
freq_porta_7to10GHz, amp_porta_7to10GHz, fase_porta_7to10GHz=ImportS2P("C:/Users/molin/medidas mK/(sample2) Medidas mK CHIP1 2024_06_26/S21_span7-10GHz_-5dBm.csv"\
                                       ,Delimiter = " ", Cols = (0,1,2), Skip_head=1)
freq_porta_10to15GHz, amp_porta_10to15GHz, fase_porta_10to15GHz=ImportS2P("C:/Users/molin/medidas mK/(sample2) Medidas mK CHIP1 2024_06_26/S21_span10-15GHz_-5dBm.csv"\
                                       ,Delimiter = " ", Cols = (0,1,2), Skip_head=1)

# %%
fig, ax = plt.subplots(1, 1, figsize=(30,20))

ax.plot(fundo_freq_span18GHz, fundo_amp_span18GHz, linewidth=2, color='blue')
ax.plot(freq_porta_0to4GHz, amp_porta_0to4GHz, linewidth=2, color='black')
ax.plot(freq_porta_4to7GHz, amp_porta_4to7GHz, linewidth=2, color='black')
ax.plot(freq_porta_7to10GHz, amp_porta_7to10GHz, linewidth=2, color='black')
ax.plot(freq_porta_10to15GHz, amp_porta_10to15GHz, linewidth=2, color='black')
ax.set_title("Pico 1 - Amplitude $S_{21}$", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=28)
ax.set_ylabel(r"Transmissão (dB)", fontsize=28)
ax.tick_params(axis='both', which='major', labelsize=28)
ax.set_xlim(0,15e9)
# Out:
# (0.0, 15000000000.0)

# %%
j=0

# %%
#lista=np.linspace(0,15,150) * (10**9)

fig, ax = plt.subplots(1, 1, figsize=(30,20))

#ax.plot(fundo_freq_span18GHz, fundo_fase_span18GHz, linewidth=2, color='black')
ax.plot(freq_porta_0to4GHz, fase_porta_0to4GHz, linewidth=3, color='blue')
ax.plot(freq_porta_4to7GHz, fase_porta_4to7GHz, linewidth=3, color='blue')
ax.plot(freq_porta_7to10GHz, fase_porta_7to10GHz, linewidth=3, color='blue')
ax.plot(freq_porta_10to15GHz, fase_porta_10to15GHz, linewidth=3, color='blue')
ax.set_title("Pico 1 - Amplitude $S_{21}$", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=28)
ax.set_ylabel(r"Transmissão (dB)", fontsize=28)
ax.tick_params(axis='both', which='major', labelsize=28)
ax.set_xlim(j*(10**9),(j+0.1)*(10**9))
j=j+0.1

# %%
fig, ax = plt.subplots(1, 1, figsize=(30,20))

ax.plot(fundo_freq_span18GHz, fundo_fase_span18GHz, linewidth=2, color='blue')
ax.plot(freq_porta_0to4GHz, fase_porta_0to4GHz, linewidth=2, color='black')
ax.plot(freq_porta_4to7GHz, fase_porta_4to7GHz, linewidth=2, color='black')
ax.plot(freq_porta_7to10GHz, fase_porta_7to10GHz, linewidth=2, color='black')
ax.plot(freq_porta_10to15GHz, fase_porta_10to15GHz, linewidth=2, color='black')
ax.set_title("Pico 1 - Amplitude $S_{21}$", fontsize=25)
ax.set_xlabel(r"Frequencia (GHz)", fontsize=28)
ax.set_ylabel(r"Transmissão (dB)", fontsize=28)
ax.tick_params(axis='both', which='major', labelsize=28)
ax.set_xlim(10.8e9,11e9)
# Out:
# (10800000000.0, 11000000000.0)
